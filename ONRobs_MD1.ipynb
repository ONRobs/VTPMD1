# %% [markdown]
# # MD1
#
# Mājasdarba ietvaros izveidotais FTP apraksta 3., 5., un 6. lietvārdu deklināciju latviešu valodā.
#
# 3. Deklinācijas vārdi:
# - medus
# - alus
# - lietus
# 5. deklinācijas vārdi:
# - upe
# - zvaigzne
# - cepure
# 6. deklinācijas vārdi:
# - nakts
# - auss
# - acs
# - ļaudis (tikai daudzskaitlis)
#
# Saite uz projekta repozitoriju:
# https://github.com/ONRobs/VTPMD1/

# %%
# !pip install hfst==3.16.0.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 MB 2.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ```
# Multichar_Symbols +N +Sg +Pl +Nom +Gen +Dat +Acc +Loc
#
# LEXICON Root
# Noun ;
#
# LEXICON Noun
#
# med N3dekl;
# al N3dekl;
# liet N3dekl;
# up N5dekl;
# zvaigzn N5dekl;
# cepur N5dekl;
# nakt N6dekl;
# aus N6dekl;
# ac N6dekl;
# ļaud N6deklPl;
#
# LEXICON N3dekl
# +N+Sg+Nom:^us #;
# +N+Sg+Gen:^us #;
# +N+Sg+Dat:^um #;
# +N+Sg+Acc:^u #;
# +N+Sg+Loc:^ū #;
# +N+Pl+Nom:^i #;
# +N+Pl+Gen:^u #;
# +N+Pl+Dat:^iem #;
# +N+Pl+Acc:^us #;
# +N+Pl+Loc:^os #;
#
# LEXICON N5dekl
# +N+Sg+Nom:^e #;
# +N+Sg+Gen:^es #;
# +N+Sg+Dat:^ei #;
# +N+Sg+Acc:^i #;
# +N+Sg+Loc:^ē #;
# +N+Pl+Nom:^es #;
# +N+Pl+Gen:^Mu #;
# +N+Pl+Dat:^ēm #;
# +N+Pl+Acc:^es #;
# +N+Pl+Loc:^ēs #;
#
# LEXICON N6dekl
# +N+Sg+Nom:^s #;
# +N+Sg+Gen:^s #;
# +N+Sg+Dat:^ij #;
# +N+Sg+Acc:^i #;
# +N+Sg+Loc:^ī #;
# +N+Pl+Nom:^is #;
# +N+Pl+Gen:^Mu #;
# +N+Pl+Dat:^īm #;
# +N+Pl+Acc:^is #;
# +N+Pl+Loc:^īs #;
#
# LEXICON N6deklPl
# +N+Pl+Nom:^is #;
# +N+Pl+Gen:^Mu #;
# +N+Pl+Dat:^īm #;
# +N+Pl+Acc:^is #;
# +N+Pl+Loc:^īs #;
# ```

# %%
# !wget https://raw.githubusercontent.com/ONRobs/VTPMD1/refs/heads/main/md1.lexc
# Out:
# --2026-03-30 13:20:12--  https://raw.githubusercontent.com/ONRobs/VTPMD1/refs/heads/main/md1.lexc
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 905 [text/plain]
# Saving to: ‘md1.lexc’
#
# md1.lexc            100%[===================>]     905  --.-KB/s    in 0s
#
# 2026-03-30 13:20:13 (30.6 MB/s) - ‘md1.lexc’ saved [905/905]

# %%
import hfst

generator = hfst.compile_lexc_file('md1.lexc')

# %%
InsertJ = hfst.regex('[..] -> j || [b | f | m | p | v] _ "^" M')

ZNReplacement = hfst.regex('z n -> ž ņ ||  _ "^" M')
DReplacement = hfst.regex('d -> ž ||  _ "^" M')
TReplacement = hfst.regex('t -> š ||  _ "^" M')

MCleanup = hfst.regex('M -> 0')
Cleanup = hfst.regex('"^" -> 0')

# %%
from hfst import regex, HfstTransducer, compose

print(f"Type of generator: {type(generator)}")
cascade = compose((generator, InsertJ, ZNReplacement, DReplacement, TReplacement, MCleanup, Cleanup))
# Out:
# Type of generator: <class 'hfst.libhfst.HfstTransducer'>

# %%
for noun in ["med", "al", "liet", "up", "zvaigzn", "cepur", "nakt", "aus", "ac", "ļaud"]:
    for number in ["Sg", "Pl"]:
        for form in ["Nom", "Gen", "Dat", "Acc", "Loc"]:
            result = cascade.lookup(noun + "+N+" + number + "+" + form)
            if result:
                print(noun + "+N+" + number + "+" + form + " - " + result[0][0].replace("@_EPSILON_SYMBOL_@", ""))
            else:
                print(noun + "+N+" + number + "+" + form + " - ")
# Out:
# med+N+Sg+Nom - medus
# med+N+Sg+Gen - medus
# med+N+Sg+Dat - medum
# med+N+Sg+Acc - medu
# med+N+Sg+Loc - medū
# med+N+Pl+Nom - medi
# med+N+Pl+Gen - medu
# med+N+Pl+Dat - mediem
# med+N+Pl+Acc - medus
# med+N+Pl+Loc - medos
# al+N+Sg+Nom - alus
# al+N+Sg+Gen - alus
# al+N+Sg+Dat - alum
# al+N+Sg+Acc - alu
# al+N+Sg+Loc - alū
# al+N+Pl+Nom - ali
# al+N+Pl+Gen - alu
# al+N+Pl+Dat - aliem
# al+N+Pl+Acc - alus
# al+N+Pl+Loc - alos
# liet+N+Sg+Nom - lietus
# liet+N+Sg+Gen - lietus
# liet+N+Sg+Dat - lietum
# liet+N+Sg+Acc - lietu
# liet+N+Sg+Loc - lietū
# liet+N+Pl+Nom - lieti
# liet+N+Pl+Gen - lietu
# liet+N+Pl+Dat - lietiem
# liet+N+Pl+Acc - lietus
# liet+N+Pl+Loc - lietos
# up+N+Sg+Nom - upe
# up+N+Sg+Gen - upes
# up+N+Sg+Dat - upei
# up+N+Sg+Acc - upi
# up+N+Sg+Loc - upē
# up+N+Pl+Nom - upes
# up+N+Pl+Gen - upju
# up+N+Pl+Dat - upēm
# up+N+Pl+Acc - upes
# up+N+Pl+Loc - upēs
# zvaigzn+N+Sg+Nom - zvaigzne
# zvaigzn+N+Sg+Gen - zvaigznes
# zvaigzn+N+Sg+Dat - zvaigznei
# ...
